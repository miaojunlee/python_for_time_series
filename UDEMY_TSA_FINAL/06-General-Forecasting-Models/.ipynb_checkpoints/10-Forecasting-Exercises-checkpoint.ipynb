# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Forecasting Exercises
# This exercise walks through a SARIMA prediction and forecast similar to the one done on the Mauna Loa CO₂ dataset.<br>
# This time we're using a seasonal time series of California Hospitality Industry Employees.
#
# <div class="alert alert-danger" style="margin: 10px"><strong>IMPORTANT NOTE!</strong> Make sure you don't run the cells directly above the example output shown, <br>otherwise you will end up writing over the example output!</div>

# %%
# RUN THIS CELL
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Load specific forecasting tools
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima                              # for determining ARIMA orders

# Load specific evaluation tools
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# Load datasets
df = pd.read_csv('../Data/HospitalityEmployees.csv',index_col='Date',parse_dates=True)
df.index.freq = 'MS'
print(len(df))
print(df.head())
# Out:
# 348
#             Employees
# Date
# 1990-01-01     1064.5
# 1990-02-01     1074.5
# 1990-03-01     1090.0
# 1990-04-01     1097.4
# 1990-05-01     1108.7

# %% [markdown]
# So <tt>df</tt> has 348 records and one column. The data represents the number of employees in thousands of persons as monthly averages from January, 1990 to December 2018.

# %% [markdown]
# ### 1. Plot the source data
# Create a line chart of the dataset. Optional: add a title and y-axis label.

# %%
## CODE HERE

df['Employees'].plot(figsize=(12,6), title='California Hospitality Industry Employees')
plt.ylabel('Thousands of Persons' );

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 2. Run an ETS Decomposition
# Use an 'additive' model.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
rcParams['figure.figsize']=12,8

ets=seasonal_decompose(df['Employees'], model='additive')
ets.plot();

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 3. Run <tt>pmdarima.auto_arima</tt> to obtain recommended orders
# This may take awhile as there are a lot of combinations to evaluate.

# %%
auto_arima(df['Employees'], seasonal=True, m=12).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  348
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1098.307
# Date:                              Mon, 13 Apr 2020   AIC                           2210.614
# Time:                                      13:50:45   BIC                           2237.559
# Sample:                                           0   HQIC                          2221.343
#                                               - 348
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0004      0.005      0.081      0.935      -0.010       0.011
# ar.L1          0.9224      0.046     20.136      0.000       0.833       1.012
# ma.L1         -0.9441      0.070    -13.464      0.000      -1.082      -0.807
# ma.L2          0.1317      0.060      2.200      0.028       0.014       0.249
# ar.S.L12       0.9977      0.001    721.010      0.000       0.995       1.000
# ma.S.L12      -0.7574      0.042    -17.928      0.000      -0.840      -0.675
# sigma2        29.1976      1.703     17.148      0.000      25.860      32.535
# ===================================================================================
# Ljung-Box (Q):                       32.11   Jarque-Bera (JB):                66.35
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                            -0.09
# Prob(H) (two-sided):                  0.45   Kurtosis:                         5.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# DON'T WRITE HERE
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  348
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1134.664
# Date:                            Wed, 27 Mar 2019   AIC                           2277.328
# Time:                                    13:12:10   BIC                           2292.726
# Sample:                                         0   HQIC                          2283.459
#                                             - 348
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0477      0.292     -0.163      0.870      -0.620       0.524
# ar.S.L12       0.5291      0.040     13.286      0.000       0.451       0.607
# ar.S.L24       0.4303      0.041     10.453      0.000       0.350       0.511
# sigma2        37.2952      2.157     17.294      0.000      33.068      41.522
# ===================================================================================
# Ljung-Box (Q):                       99.53   Jarque-Bera (JB):                51.67
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -0.29
# Prob(H) (two-sided):                  0.42   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# You should see a recommended ARIMA Order of (0,1,0) combined with a seasonal order of (2,0,0,12).
# ### 4. Split the data into train/test sets
# Set one year (12 records) for testing. There is more than one way to do this!

# %%
train=df.iloc[:-12]
test=df.iloc[-12:]

print(train.shape, test.shape)
# Out:
# (336, 1) (12, 1)

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 5. Fit a SARIMA(0,1,0)(2,0,0,12) model to the training set

# %%
model=SARIMAX(train, order=(1,1,2), seasonal_order=(1,0,1,12))

results= model.fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            Employees   No. Observations:                  336
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1058.058
# Date:                              Mon, 13 Apr 2020   AIC                           2128.117
# Time:                                      13:54:52   BIC                           2151.001
# Sample:                                  01-01-1990   HQIC                          2137.240
#                                        - 12-01-2017
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9242      0.044     21.238      0.000       0.839       1.009
# ma.L1         -0.9588      0.070    -13.635      0.000      -1.097      -0.821
# ma.L2          0.1502      0.061      2.464      0.014       0.031       0.270
# ar.S.L12       0.9973      0.001    734.623      0.000       0.995       1.000
# ma.S.L12      -0.7523      0.044    -17.177      0.000      -0.838      -0.666
# sigma2        28.7536      1.683     17.086      0.000      25.455      32.052
# ===================================================================================
# Ljung-Box (Q):                       29.91   Jarque-Bera (JB):                73.30
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                            -0.17
# Prob(H) (two-sided):                  0.63   Kurtosis:                         5.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# DON'T WRITE HERE
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                          Employees   No. Observations:                  336
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1095.407
# Date:                            Wed, 27 Mar 2019   AIC                           2196.814
# Time:                                    13:12:24   BIC                           2208.256
# Sample:                                01-01-1990   HQIC                          2201.375
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.5204      0.040     13.051      0.000       0.442       0.599
# ar.S.L24       0.4385      0.041     10.593      0.000       0.357       0.520
# sigma2        37.1907      2.165     17.175      0.000      32.947      41.435
# ===================================================================================
# Ljung-Box (Q):                      102.80   Jarque-Bera (JB):                56.66
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.35
# Prob(H) (two-sided):                  0.74   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### 6. Obtain predicted values

# %%
start=len(train)
end = len(train) + len(test)-1

predictions=results.predict(start, end, typ='levels').rename('SARIMAX with order (1,1,2)/(1,0,1,12)')

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 7. Plot predictions against known values
# Optional: add a title and y-axis label.

# %%
test.plot(figsize=(12,6), title='California Hospitality Industry Employees')
predictions.plot(figsize=(12,6), legend=True)
plt.ylabel('Thousands of Persons');

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 8. Evaluate the Model using MSE and RMSE
# You can run both from the same cell if you want.

# %%
mean_squared_error

# %%
from statsmodels.tools.eval_measures import rmse, mse

rmse=rmse(test['Employees'], predictions)
mse=mse(test['Employees'],predictions)

print("SARIMA(1,1,2)(1,0,1,12) MSE Error:",mse)
print("SARIMA(1,1,2)(1,0,1,12) RMSE Error:",rmse)
# Out:
# SARIMA(1,1,2)(1,0,1,12) MSE Error: 77.47251916376227
# SARIMA(1,1,2)(1,0,1,12) RMSE Error: 8.801847485827182

# %%
# DON'T WRITE HERE
# Out:
# SARIMA(0,1,0)(2,0,0,12) MSE Error: 182.8506646
# SARIMA(0,1,0)(2,0,0,12) RMSE Error: 13.52222854

# %% [markdown]
# ### 9. Retrain the model on the full data and forecast one year into the future

# %%
model=SARIMAX(df['Employees'], order=(1,1,2), seasonal_order=(1,0,1,12))
results=model.fit()

start=len(df)
end = len(df) + 12 -1 

predictions=results.predict(start,end)

# %%
predictions
# Out:
# 2019-01-01    1963.875223
# 2019-02-01    1986.815477
# 2019-03-01    2005.996539
# 2019-04-01    2030.331733
# 2019-05-01    2050.312852
# 2019-06-01    2067.138783
# 2019-07-01    2074.919093
# 2019-08-01    2076.483903
# 2019-09-01    2056.895740
# 2019-10-01    2051.838893
# 2019-11-01    2047.924472
# 2019-12-01    2053.890216
# Freq: MS, dtype: float64

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 10. Plot the forecasted values alongside the original data
# Optional: add a title and y-axis label.

# %%
df['Employees'].plot(figsize=(12,6), title='California Hospitality Industry Employees')
predictions.plot(figsize=(12,6))
plt.ylabel('Thousands of Persons');

# %%
# DON'T WRITE HERE

# %% [markdown]
# ## Great job!
